# %% [markdown]
# # Bit field

# %%
from konfoo import Index, Byteorder, Bit

# %% [markdown]
# ## Item

# %% [markdown]
# Item type of the `field` class.

# %%
Bit.item_type
# Out:
# ItemClass.Bit = 41

# %% [markdown]
# Checks if the `field` class is a `bit` field.

# %%
Bit.is_bit()
# Out:
# True

# %% [markdown]
# Checks if the `field` class is a `boolean` field.

# %%
Bit.is_bool()
# Out:
# False

# %% [markdown]
# Checks if the `field` class is a `decimal` number field.

# %%
Bit.is_decimal()
# Out:
# True

# %% [markdown]
# Checks if the `field` class is a `floating point` number field.

# %%
Bit.is_float()
# Out:
# False

# %% [markdown]
# Checks if the `field` class is a `pointer` field.

# %%
Bit.is_pointer()
# Out:
# False

# %% [markdown]
# Checks if the `field` class is a `stream` field.

# %%
Bit.is_stream()
# Out:
# False

# %% [markdown]
# Checks if the `field` class is a `string` field.

# %%
Bit.is_stream()
# Out:
# False

# %% [markdown]
# ## Field

# %%
bit = Bit(number=0, align_to=None)

# %%
bit = Bit(0)

# %% [markdown]
# ### Field view

# %%
bit
# Out:
# Bit(index=Index(byte=0, bit=0, address=0, base_address=0, update=False), alignment=Alignment(byte_size=1, bit_offset=0), bit_size=1, value=0)

# %%
str(bit)
# Out:
# 'Bit(Index(byte=0, bit=0, address=0, base_address=0, update=False), Alignment(byte_size=1, bit_offset=0), 1, 0)'

# %%
repr(bit)
# Out:
# 'Bit(index=Index(byte=0, bit=0, address=0, base_address=0, update=False), alignment=Alignment(byte_size=1, bit_offset=0), bit_size=1, value=0)'

# %% [markdown]
# ### Field name

# %%
bit.name
# Out:
# 'Bit'

# %% [markdown]
# ### Field index

# %%
bit.index
# Out:
# Index(byte=0, bit=0, address=0, base_address=0, update=False)

# %% [markdown]
# Byte `index` of the `field` within the `byte stream`.

# %%
bit.index.byte
# Out:
# 0

# %% [markdown]
# Bit offset relative to the byte `index` of the `field` within the `byte stream`.

# %%
bit.index.bit
# Out:
# 0

# %% [markdown]
# Absolute address of the `field` within the `data source`.

# %%
bit.index.address
# Out:
# 0

# %% [markdown]
# Base address of the `byte stream` within the `data source`.

# %%
bit.index.base_address
# Out:
# 0

# %% [markdown]
# Indexes the `field` and returns the `index` after the `field`.

# %%
bit.index_field(index=Index())
# Out:
# Index(byte=0, bit=1, address=0, base_address=0, update=False)

# %% [markdown]
# ### Field alignment

# %%
bit.alignment
# Out:
# Alignment(byte_size=1, bit_offset=0)

# %% [markdown]
# Byte size of the `field group` which the `field` is *aligned* to.

# %%
bit.alignment.byte_size
# Out:
# 1

# %% [markdown]
# Bit offset of the `field` within its *aligned* `field group`.

# %%
bit.alignment.bit_offset
# Out:
# 0

# %% [markdown]
# ### Field size

# %%
bit.bit_size
# Out:
# 1

# %% [markdown]
# ### Field byte order

# %%
bit.byte_order
# Out:
# Byteorder.auto = 'auto'

# %%
bit.byte_order.value
# Out:
# 'auto'

# %%
bit.byte_order.name
# Out:
# 'auto'

# %%
bit.byte_order = 'auto'

# %%
bit.byte_order = Byteorder.auto

# %% [markdown]
# ### Field value

# %% [markdown]
# Checks if the decimal `field` is signed or unsigned.

# %%
bit.signed
# Out:
# False

# %% [markdown]
# Maximal decimal `field` value.

# %%
bit.max()
# Out:
# 1

# %% [markdown]
# Minimal decimal `field` value.

# %%
bit.min()
# Out:
# 0

# %% [markdown]
# Returns the bit `field` value as an integer number.

# %%
bit.value
# Out:
# 0

# %% [markdown]
# Returns the decimal `field` value *aligned* to its `field group` as a number of bytes.

# %%
bytes(bit)
# Out:
# b'\x00'

# %%
bytes(bit).hex()
# Out:
# '00'

# %% [markdown]
# Returns the decimal `field` value as an integer number.

# %%
int(bit)
# Out:
# 0

# %% [markdown]
# Returns the decimal `field` value as an floating point number.

# %%
float(bit)
# Out:
# 0.0

# %% [markdown]
# Returns the decimal `field` value as a lowercase hexadecimal string prefixed with `0x`.

# %%
hex(bit)
# Out:
# '0x0'

# %% [markdown]
# Returns the decimal `field` value as a binary string prefixed with `0b`.

# %%
bin(bit)
# Out:
# '0b0'

# %% [markdown]
# Returns the decimal `field` value as an octal string prefixed with `0o`.

# %%
oct(bit)
# Out:
# '0o0'

# %% [markdown]
# Returns the decimal `field` value as a boolean value.

# %%
bool(bit)
# Out:
# False

# %% [markdown]
# Returns the decimal `field` value as a signed integer number.

# %%
bit.as_signed()
# Out:
# 0

# %% [markdown]
# Returns the decimal `field` value as an unsigned integer number.

# %%
bit.as_unsigned()
# Out:
# 0

# %% [markdown]
# ### Field metadata

# %% [markdown]
# Returns the ``meatadata`` of the ``field`` as an ordered dictionary.

# %%
bit.describe()
# Out:
# {'address': 0,
#  'alignment': [1, 0],
#  'class': 'Bit',
#  'index': [0, 0],
#  'max': 1,
#  'min': 0,
#  'name': 'Bit',
#  'order': 'auto',
#  'signed': False,
#  'size': 1,
#  'type': 'Field',
#  'value': 0}

# %% [markdown]
# ### Deserialize

# %%
bit.deserialize(bytes.fromhex('01'), byte_order='little')
# Out:
# Index(byte=0, bit=1, address=0, base_address=0, update=False)

# %%
bit.value
# Out:
# 1

# %%
bytes(bit)
# Out:
# b'\x01'

# %%
bytes(bit).hex()
# Out:
# '01'

# %%
int(bit)
# Out:
# 1

# %%
float(bit)
# Out:
# 1.0

# %%
hex(bit)
# Out:
# '0x1'

# %%
bin(bit)
# Out:
# '0b1'

# %%
oct(bit)
# Out:
# '0o1'

# %%
bool(bit)
# Out:
# True

# %% [markdown]
# ### Serialize

# %%
buffer = bytearray()

# %%
bit.value = 1

# %%
bit.value = 1.0

# %%
bit.value = 0x01

# %%
bit.value = 0b1

# %%
bit.value = 0o1

# %%
bit.value = True

# %%
bit.value = 1

# %%
bit.serialize(buffer, byte_order='little')
# Out:
# Index(byte=0, bit=1, address=0, base_address=0, update=False)

# %%
buffer.hex()
# Out:
# '01'

# %%
bytes(bit).hex()
# Out:
# '01'
